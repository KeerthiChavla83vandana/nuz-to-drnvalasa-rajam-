# %%
import folium
from collections import namedtuple
import numpy as np

# %%
#nuz to my village
from branca.element import Figure

nuzvid=folium.Map(location=[16.7850, 80.8488],zoom_start=10)
#add markers
#making markers
folium.Marker(location=[18.5004, 83.5949],popup="village in rajam",tooltip='dosari destination',icon=folium.Icon(color='yellow',prefix='fa',icon='anchor')).add_to(nuzvid)
#nuzvid marker
folium.Marker(location=[16.7850, 80.8488],popup='nuzvid',tooltip='source nuzvid',icon=folium.Icon(color='red',icon='none')).add_to(nuzvid)

#vizayawada marker
folium.Marker(location=[16.5062, 80.6480],popup='enroute to vizayawada',tooltip='one way ',icon=folium.Icon(color='red',icon='none')).add_to(nuzvid)

#vizag
folium.Marker(location=[17.6868, 83.2185],popup='enroute to vizag',tooltip='middle of journey ',icon=folium.Icon(color='pink',icon='none')).add_to(nuzvid)

#chilakapalem
folium.Marker(location=[18.2710, 83.8022],popup=' vizag to chilakapalem',tooltip='another way to rajam ',icon=folium.Icon(color='pink',icon='none')).add_to(nuzvid)

#rajam
folium.Marker(location=[18.4556, 83.6494],popup=' this mandal famous for all',tooltip='my mandal',icon=folium.Icon(color='green',prefix='glyphicon',icon='none')).add_to(nuzvid)

#adding user defined icon
#durga gudi
folium.Marker(location=[16.5154,80.6059],popup="<strong>durga malleswara temple</strong>",tooltip='bejawada durga gudi',icon=folium.features.CustomIcon('https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSi0TQccnMRonDLkWKoyWn0SZ1qhINFjOwIqQ&usqp=CAU',icon_size=(60,60))).add_to(nuzvid)

#bridge
folium.Marker(location=[17.004393,81.783325],popup="<strong>RAJMUNDRY BRIDGE</strong>",tooltip='bridge',icon=folium.features.CustomIcon('https://cdn-icons-png.flaticon.com/128/2138/2138687.png',icon_size=(65,60))).add_to(nuzvid)

#samarlakota
folium.Marker(location=[17.0500,82.1679],popup="<strong> BHEEMESWARA TEMPLE</strong>",tooltip='SAMARLAKOTA',icon=folium.features.CustomIcon('https://icon-library.com/images/historical-icon/historical-icon-5.jpg',icon_size=(50,50))).add_to(nuzvid)

#hisotical place
folium.Marker(location=[18.3273, 82.8775],popup='HISOTRICAL PLACE ARAKU',tooltip="araku",icon=folium.features.CustomIcon('https://cdn-icons.flaticon.com/png/512/3660/premium/3660504.png?token=exp=1660643570~hmac=c568b44a1e15aabe8287e5797ff36609',icon_size=(65,60))).add_to(nuzvid)


#raghu clg vizag
folium.Marker(location=[17.9942,83.4150],popup="<strong>RAGHU ENGINEERING COLLEGE</strong>",tooltip='betch clg in vizag',icon=folium.features.CustomIcon('https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSi0TQccnMRonDLkWKoyWn0SZ1qhINFjOwIqQ&usqp=CAU',icon_size=(60,60))).add_to(nuzvid)

#hotel in vizag
folium.Marker(location=[17.7262,83.3033],popup="sri ramsai parlour",tooltip='meals hotel',icon=folium.features.CustomIcon('https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRwYyacrAxUoxYxSkS4XxljRxVHD3MtpmFLnQ&usqp=CAU',icon_size=(60,60))).add_to(nuzvid)

#vizyanagram busstand
folium.Marker(location=[18.56917,83.13191],popup="BUSTAND IN VIZAYANAGARAM",tooltip='bustand',icon=folium.features.CustomIcon('https://cdn-icons.flaticon.com/png/128/3160/premium/3160658.png',icon_size=(60,60))).add_to(nuzvid)


#care hospital
folium.Marker(location=[18.451769,83.6580217],popup="GMR CARE HOSPITAL",tooltip='multispeciality hospital',icon=folium.features.CustomIcon('https://cdn-icons-png.flaticon.com/256/7413/7413417.png',icon_size=(60,60))).add_to(nuzvid)
#shop
folium.Marker(location=[17.3573, 82.5443],popup="d mart at tuni",tooltip='tuni ',icon=folium.features.CustomIcon('https://t4.ftcdn.net/jpg/00/97/00/05/240_F_97000552_d8RwiZAnFewznisQphPtjyxxRNAAZQ92.jpg',icon_size=(60,60))).add_to(nuzvid)

#shop
folium.Marker(location=[18.500423, 83.5949567],popup="my village jagadurga kirana shop",tooltip='shop ',icon=folium.features.CustomIcon('https://t4.ftcdn.net/jpg/00/97/00/05/240_F_97000552_d8RwiZAnFewznisQphPtjyxxRNAAZQ92.jpg',icon_size=(60,60))).add_to(nuzvid)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: UserWarning: color argument of Icon should be one of: {'lightblue', 'black', 'darkred', 'blue', 'darkpurple', 'cadetblue', 'lightgreen', 'red', 'lightred', 'lightgray', 'orange', 'purple', 'darkblue', 'beige', 'green', 'darkgreen', 'gray', 'pink', 'white'}.
#   import sys

# %%
from folium import vector_layers

#making markers
folium.Marker(location=[18.5004, 83.5949],popup="village in rajam",tooltip='dosari destination',icon=folium.Icon(color='yellow',prefix='fa',icon='anchor')).add_to(nuzvid)
#nuzvid marker
folium.Marker(location=[16.7850, 80.8488],popup='nuzvid',tooltip='source nuzvid',icon=folium.Icon(color='red',icon='none')).add_to(nuzvid)

# TAGGING NUZVID TO DOSARI
nuz=[16.7850, 80.8488]
dosari=[18.5004, 83.5949]

coord_1=[[16.7850, 80.8488],[16.7107, 81.0952],[16.8073, 81.5316 ],[16.8971, 81.6634],[17.0005, 81.8040],[17.0500, 82.1679],[17.2789, 82.4013],[17.6896, 83.0024], [17.6970, 83.1466],[17.6868, 83.2185],[17.7664, 83.2505],[18.1067,83.3956],[18.2858, 83.5363],[18.3105, 83.5683],[18.5004, 83.5949],[18.445,83.62902],[18.5004, 83.594]]

coord_2=[[16.5062, 80.6480],[16.7850, 80.8488],[16.7107, 81.0952],[16.8073, 81.5316 ],[16.8971, 81.6634],[17.0005, 81.8040],[17.0500, 82.1679],[17.2789, 82.4013],[17.6896, 83.0024], [17.6970, 83.1466],[17.6868, 83.2185],[17.9325, 83.4268],[18.2710, 83.8022],[18.3494, 83.7566],[18.4556, 83.6494],[18.455772,83.622867],[18.5004, 83.5949]]



# tagging line
f1=folium.FeatureGroup("way 1")
f2=folium.FeatureGroup("way2")

line1=folium.vector_layers.PolyLine(coord_1,popup='way 1 -> from nuz to drn valasa via vizag',tooltip='way 1',color='blue',weight=5).add_to(f1)
folium.PolyLine(locations=[[16.7850, 80.8488],[16.5062, 80.6480]],color='red').add_to(nuzvid)

line2=folium.vector_layers.PolyLine(coord_2,popup='way 2 -> from nuz to drn valasa via vizag',tooltip='way 2',color='red',weight=5).add_to(f2)
f1.add_to(nuzvid)
f2.add_to(nuzvid)


folium.LayerControl().add_to(nuzvid)
nuzvid
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: UserWarning: color argument of Icon should be one of: {'lightblue', 'black', 'darkred', 'blue', 'darkpurple', 'cadetblue', 'lightgreen', 'red', 'lightred', 'lightgray', 'orange', 'purple', 'darkblue', 'beige', 'green', 'darkgreen', 'gray', 'pink', 'white'}.
#   after removing the cwd from sys.path.
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
# ...
